# %%
# Install and Import Library

# !pip install pyspellchecker
# !pip install scattertext
# !pip install nltk

# Import Data Preprocessing and Wrangling libraries
import re
from tqdm.notebook import tqdm
import pandas as pd 
import numpy as np
from datetime import datetime

# Import NLP Libraries
import nltk

# Import Visualization Libraries
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import random 

# Downloading periphrals
nltk.download('stopwords')
stop_words = stopwords.words('english')

def clean_tweet(tweet):
    if type(tweet) == np.float:
        return ""
    # lowercase all the letters
    temp = tweet.lower()
    
    temp = re.sub("'", "", temp) # to avoid removing contractions in english
    
    # remove hashtages and mentions
    temp = re.sub("@[A-Za-z0-9_]+","", temp)
    temp = re.sub("#[A-Za-z0-9_]+","", temp)
    
    # remove links
    temp = re.sub(r'http\S+', '', temp)
    temp = re.sub(r"www.\S+", "", temp)
    
    # remove punctuations
    temp = re.sub('[()!?]', ' ', temp)
    temp = re.sub('\[.*?\]',' ', temp)
    
    # flitering non-alphanumeric characters
    temp = re.sub("[^a-z0-9]"," ", temp)
    
    # remove stop word
    temp = temp.split()
    temp = [w for w in temp if not w in stop_words]
    
    # put text into a list 
    temp = " ".join(word for word in temp)
    return temp
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/xingyuchen/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pandas as pd
df = pd.read_csv('./data/prochoice_prolife.csv')
df.head()
# Out:
#    Unnamed: 0            author_id           author_name author_username  \
# 0       28588             73506221  Oregon Right to Life          OR_RTL
# 1       28587             96631851     αιяgσ*мαтι¢*σρтιχ     sacraficial
# 2       28586           3041829701                   skb        skb37027
# 3       28537            177260708  Right To Life League    Right2LifeLg
# 4       27450  1523376591052582912       No Forced Birth   NoForcedBirth
#
#                   created_at                   id  \
# 0  2022-06-23 00:00:06+00:00  1539760170900799490
# 1  2022-06-23 00:01:14+00:00  1539760456977395712
# 2  2022-06-23 00:04:30+00:00  1539761277702213633
# 3  2022-06-23 00:09:50+00:00  1539762620055552001
# 4  2022-06-23 00:09:57+00:00  1539762647922421763
#
#                                       public_metrics  \
# 0  {'retweet_count': 5, 'reply_count': 0, 'like_c...
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 2  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 3  {'retweet_count': 6, 'reply_count': 3, 'like_c...
# 4  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                 text  retweet_count  \
# 0  We know that unsupported pregnancies can gener...              5
# 1  If you are murdered by a George W. Bush weapon...              0
# 2  .@MarshaBlackburn so much for #ProLife. https:...              0
# 3  Follow our instagram for more posts like this!...              6
# 4  Another classy tweet from the forced birth cro...              0
#
#    like_count  target
# 0          13       1
# 1           0       1
# 2           0       1
# 3          19       1
# 4           1       0

# %%
df = df[['created_at', 'text', 'retweet_count', 'like_count', 'target']]
df
# Out:
#                       created_at  \
# 0      2022-06-23 00:00:06+00:00
# 1      2022-06-23 00:01:14+00:00
# 2      2022-06-23 00:04:30+00:00
# 3      2022-06-23 00:09:50+00:00
# 4      2022-06-23 00:09:57+00:00
# ...                          ...
# 56035  2022-07-03 23:57:19+00:00
# 56036  2022-07-03 23:57:37+00:00
# 56037  2022-07-03 23:57:58+00:00
# 56038  2022-07-03 23:58:20+00:00
# 56039  2022-07-03 23:59:36+00:00
#
#                                                     text  retweet_count  \
# 0      We know that unsupported pregnancies can gener...              5
# 1      If you are murdered by a George W. Bush weapon...              0
# 2      .@MarshaBlackburn so much for #ProLife. https:...              0
# 3      Follow our instagram for more posts like this!...              6
# 4      Another classy tweet from the forced birth cro...              0
# ...                                                  ...            ...
# 56035  Next June is going to be more fun #ProLife htt...              1
# 56036  @Hammock_Thomas @MariaLaoise I'm alarmed to he...              0
# 56037  At a #WomensRights and #prochoice rally https:...              0
# 56038  Je refuse leur vaccin expérimental. \n#monCorp...              2
# 56039                 #prochoice https://t.co/TymBKe6sT1              1
#
#        like_count  target
# 0              13       1
# 1               0       1
# 2               0       1
# 3              19       1
# 4               1       0
# ...           ...     ...
# 56035           3       1
# 56036           1       1
# 56037           0       0
# 56038           4       0
# 56039           4       0
#
# [56040 rows x 5 columns]

# %%
data = df.copy()
data['original_text'] = df['text']
data['datetime'] = df["created_at"]
data = data.drop('created_at', axis=1)
data['datetime'] = data['datetime'].astype(str).apply(lambda x: x.split('+')[0])
data['datetime'] = data.datetime.apply(lambda x: datetime.strptime(x, "%Y-%m-%d %H:%M:%S"))
data
# Out:
#                                                     text  retweet_count  \
# 0      We know that unsupported pregnancies can gener...              5
# 1      If you are murdered by a George W. Bush weapon...              0
# 2      .@MarshaBlackburn so much for #ProLife. https:...              0
# 3      Follow our instagram for more posts like this!...              6
# 4      Another classy tweet from the forced birth cro...              0
# ...                                                  ...            ...
# 56035  Next June is going to be more fun #ProLife htt...              1
# 56036  @Hammock_Thomas @MariaLaoise I'm alarmed to he...              0
# 56037  At a #WomensRights and #prochoice rally https:...              0
# 56038  Je refuse leur vaccin expérimental. \n#monCorp...              2
# 56039                 #prochoice https://t.co/TymBKe6sT1              1
#
#        like_count  target                                      original_text  \
# 0              13       1  We know that unsupported pregnancies can gener...
# 1               0       1  If you are murdered by a George W. Bush weapon...
# 2               0       1  .@MarshaBlackburn so much for #ProLife. https:...
# 3              19       1  Follow our instagram for more posts like this!...
# 4               1       0  Another classy tweet from the forced birth cro...
# ...           ...     ...                                                ...
# 56035           3       1  Next June is going to be more fun #ProLife htt...
# 56036           1       1  @Hammock_Thomas @MariaLaoise I'm alarmed to he...
# 56037           0       0  At a #WomensRights and #prochoice rally https:...
# 56038           4       0  Je refuse leur vaccin expérimental. \n#monCorp...
# 56039           4       0                 #prochoice https://t.co/TymBKe6sT1
#
#                  datetime
# 0     2022-06-23 00:00:06
# 1     2022-06-23 00:01:14
# 2     2022-06-23 00:04:30
# 3     2022-06-23 00:09:50
# 4     2022-06-23 00:09:57
# ...                   ...
# 56035 2022-07-03 23:57:19
# 56036 2022-07-03 23:57:37
# 56037 2022-07-03 23:57:58
# 56038 2022-07-03 23:58:20
# 56039 2022-07-03 23:59:36
#
# [56040 rows x 6 columns]

# %%
tweets_text = df['text']
results = [clean_tweet(tw) for tw in tweets_text]
data['text'] = results

data
# Out:
#                                                     text  retweet_count  \
# 0      know unsupported pregnancies generate lot fear...              5
# 1      murdered george w bush weapon war died free bo...              0
# 2                                                   much              0
# 3                            follow instagram posts like              6
# 4      another classy tweet forced birth crowd idea g...              0
# ...                                                  ...            ...
# 56035                                next june going fun              1
# 56036                        im alarmed hear arrest made              0
# 56037                                              rally              0
# 56038                 je refuse leur vaccin exp rimental              2
# 56039                                                                 1
#
#        like_count  target                                      original_text  \
# 0              13       1  We know that unsupported pregnancies can gener...
# 1               0       1  If you are murdered by a George W. Bush weapon...
# 2               0       1  .@MarshaBlackburn so much for #ProLife. https:...
# 3              19       1  Follow our instagram for more posts like this!...
# 4               1       0  Another classy tweet from the forced birth cro...
# ...           ...     ...                                                ...
# 56035           3       1  Next June is going to be more fun #ProLife htt...
# 56036           1       1  @Hammock_Thomas @MariaLaoise I'm alarmed to he...
# 56037           0       0  At a #WomensRights and #prochoice rally https:...
# 56038           4       0  Je refuse leur vaccin expérimental. \n#monCorp...
# 56039           4       0                 #prochoice https://t.co/TymBKe6sT1
#
#                  datetime
# 0     2022-06-23 00:00:06
# 1     2022-06-23 00:01:14
# 2     2022-06-23 00:04:30
# 3     2022-06-23 00:09:50
# 4     2022-06-23 00:09:57
# ...                   ...
# 56035 2022-07-03 23:57:19
# 56036 2022-07-03 23:57:37
# 56037 2022-07-03 23:57:58
# 56038 2022-07-03 23:58:20
# 56039 2022-07-03 23:59:36
#
# [56040 rows x 6 columns]

# %%
# Feature Extraction
import math
data['words'] = data.text.apply(lambda x:re.findall(r'\w+', x ))
data['words_count'] = data.words.apply(len)
data['sentence_length'] = data.text.apply(len)
# data['sentence_length_in_log'] = data.sentence_length.apply(np.log)
data['hour'] = data.datetime.apply(lambda x: x.hour)
data['date'] = data.datetime.apply(lambda x: x.date())
data['month'] = data.datetime.apply(lambda x: x.month)
# data['retweet_count_in_log'] = data.retweet_count.apply(np.log)
# data['like_count_in_log'] = data.like_count.apply(np.log)
data
# Out:
#                                                     text  retweet_count  \
# 0      know unsupported pregnancies generate lot fear...              5
# 1      murdered george w bush weapon war died free bo...              0
# 2                                                   much              0
# 3                            follow instagram posts like              6
# 4      another classy tweet forced birth crowd idea g...              0
# ...                                                  ...            ...
# 56035                                next june going fun              1
# 56036                        im alarmed hear arrest made              0
# 56037                                              rally              0
# 56038                 je refuse leur vaccin exp rimental              2
# 56039                                                                 1
#
#        like_count  target                                      original_text  \
# 0              13       1  We know that unsupported pregnancies can gener...
# 1               0       1  If you are murdered by a George W. Bush weapon...
# 2               0       1  .@MarshaBlackburn so much for #ProLife. https:...
# 3              19       1  Follow our instagram for more posts like this!...
# 4               1       0  Another classy tweet from the forced birth cro...
# ...           ...     ...                                                ...
# 56035           3       1  Next June is going to be more fun #ProLife htt...
# 56036           1       1  @Hammock_Thomas @MariaLaoise I'm alarmed to he...
# 56037           0       0  At a #WomensRights and #prochoice rally https:...
# 56038           4       0  Je refuse leur vaccin expérimental. \n#monCorp...
# 56039           4       0                 #prochoice https://t.co/TymBKe6sT1
#
#                  datetime                                              words  \
# 0     2022-06-23 00:00:06  [know, unsupported, pregnancies, generate, lot...
# 1     2022-06-23 00:01:14  [murdered, george, w, bush, weapon, war, died,...
# 2     2022-06-23 00:04:30                                             [much]
# 3     2022-06-23 00:09:50                   [follow, instagram, posts, like]
# 4     2022-06-23 00:09:57  [another, classy, tweet, forced, birth, crowd,...
# ...                   ...                                                ...
# 56035 2022-07-03 23:57:19                           [next, june, going, fun]
# 56036 2022-07-03 23:57:37                  [im, alarmed, hear, arrest, made]
# 56037 2022-07-03 23:57:58                                            [rally]
# 56038 2022-07-03 23:58:20          [je, refuse, leur, vaccin, exp, rimental]
# 56039 2022-07-03 23:59:36                                                 []
#
#        words_count  sentence_length  hour        date  month  \
# 0               20              146     0  2022-06-23      6
# 1               15               85     0  2022-06-23      6
# 2                1                4     0  2022-06-23      6
# 3                4               27     0  2022-06-23      6
# 4               13               75     0  2022-06-23      6
# ...            ...              ...   ...         ...    ...
# 56035            4               19    23  2022-07-03      7
# 56036            5               27    23  2022-07-03      7
# 56037            1                5    23  2022-07-03      7
# 56038            6               34    23  2022-07-03      7
# 56039            0                0    23  2022-07-03      7
#
#        sentence_length_in_log  positive_words_count  retweet_count_in_log  \
# 0                    4.983607                     0              1.609438
# 1                    4.442651                     0                  -inf
# 2                    1.386294                     0                  -inf
# 3                    3.295837                     0              1.791759
# 4                    4.317488                     0                  -inf
# ...                       ...                   ...                   ...
# 56035                2.944439                     0              0.000000
# 56036                3.295837                     0                  -inf
# 56037                1.609438                     0                  -inf
# 56038                3.526361                     0              0.693147
# 56039                    -inf                     0              0.000000
#
#        like_count_in_log
# 0               2.564949
# 1                   -inf
# 2                   -inf
# 3               2.944439
# 4               0.000000
# ...                  ...
# 56035           1.098612
# 56036           0.000000
# 56037               -inf
# 56038           1.386294
# 56039           1.386294
#
# [56040 rows x 16 columns]

# %%
# preprocess_data = data[['retweet_count_in_log','like_count_in_log', 'words_count', 'sentence_length_in_log', 'hour', 'target']]
preprocess_data = data[['retweet_count','like_count', 'words_count', 'sentence_length', 'hour', 'target']]

preprocess_data
# Out:
#        retweet_count  like_count  words_count  sentence_length  hour  target
# 0                  5          13           20              146     0       1
# 1                  0           0           15               85     0       1
# 2                  0           0            1                4     0       1
# 3                  6          19            4               27     0       1
# 4                  0           1           13               75     0       0
# ...              ...         ...          ...              ...   ...     ...
# 56035              1           3            4               19    23       1
# 56036              0           1            5               27    23       1
# 56037              0           0            1                5    23       0
# 56038              2           4            6               34    23       0
# 56039              1           4            0                0    23       0
#
# [56040 rows x 6 columns]

# %%
preprocess_data.describe()
# Out:
#        retweet_count    like_count   words_count  sentence_length  \
# count   56040.000000  56040.000000  56040.000000     56040.000000
# mean        1.135046      5.561046     10.381103        67.771074
# std        16.148907     98.445893      8.501427        55.495964
# min         0.000000      0.000000      0.000000         0.000000
# 25%         0.000000      0.000000      3.000000        18.000000
# 50%         0.000000      0.000000      9.000000        59.000000
# 75%         0.000000      1.000000     16.000000       110.000000
# max      2009.000000  17377.000000     51.000000       268.000000
#
#                hour        target
# count  56040.000000  56040.000000
# mean      13.058547      0.510153
# std        6.908186      0.499901
# min        0.000000      0.000000
# 25%        7.000000      0.000000
# 50%       15.000000      1.000000
# 75%       19.000000      1.000000
# max       23.000000      1.000000

# %%
df = preprocess_data.drop('target', axis=1)
# normalized_df=(df-df.min())/(df.max()-df.min())
normalized_df=(df-df.mean())/df.std()
normalized_df
# Out:
#        retweet_count  like_count  words_count  sentence_length      hour
# 0           0.239332    0.075564     1.131445         1.409633 -1.890301
# 1          -0.070286   -0.056488     0.543308         0.310454 -1.890301
# 2          -0.070286   -0.056488    -1.103474        -1.149112 -1.890301
# 3           0.301256    0.136511    -0.750592        -0.734667 -1.890301
# 4          -0.070286   -0.046330     0.308054         0.130260 -1.890301
# ...              ...         ...          ...              ...       ...
# 56035      -0.008363   -0.026015    -0.750592        -0.878822  1.439083
# 56036      -0.070286   -0.046330    -0.632965        -0.734667  1.439083
# 56037      -0.070286   -0.056488    -1.103474        -1.131093  1.439083
# 56038       0.053561   -0.015857    -0.515337        -0.608532  1.439083
# 56039      -0.008363   -0.015857    -1.221101        -1.221189  1.439083
#
# [56040 rows x 5 columns]

# %%
final_result = pd.concat([preprocess_data['target'],normalized_df], axis=1)
final_result
# Out:
#        target  retweet_count  like_count  words_count  sentence_length  \
# 0           1       0.239332    0.075564     1.131445         1.409633
# 1           1      -0.070286   -0.056488     0.543308         0.310454
# 2           1      -0.070286   -0.056488    -1.103474        -1.149112
# 3           1       0.301256    0.136511    -0.750592        -0.734667
# 4           0      -0.070286   -0.046330     0.308054         0.130260
# ...       ...            ...         ...          ...              ...
# 56035       1      -0.008363   -0.026015    -0.750592        -0.878822
# 56036       1      -0.070286   -0.046330    -0.632965        -0.734667
# 56037       0      -0.070286   -0.056488    -1.103474        -1.131093
# 56038       0       0.053561   -0.015857    -0.515337        -0.608532
# 56039       0      -0.008363   -0.015857    -1.221101        -1.221189
#
#            hour
# 0     -1.890301
# 1     -1.890301
# 2     -1.890301
# 3     -1.890301
# 4     -1.890301
# ...         ...
# 56035  1.439083
# 56036  1.439083
# 56037  1.439083
# 56038  1.439083
# 56039  1.439083
#
# [56040 rows x 6 columns]

# %%
final_result.to_csv('clean.csv', index=False)
